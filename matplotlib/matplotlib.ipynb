# %%
import matplotlib.pyplot as  plt
import numpy as np
# %matplotlib inline

# %%
plt.plot([1,2,9], [1, 3, -1])
plt.show()

# %%
gp_1 = np.random.random(50) * 100 # 50 values b/w 0 and 100
gp_2 = np.random.random(50)*100

gp_1
# Out:
# array([0.93253959, 0.81209384, 0.05088978, 0.94466307, 0.10459277,
#        0.07957769, 0.2701687 , 0.60835071, 0.0519273 , 0.45846774,
#        0.68993337, 0.42693659, 0.68854047, 0.68371937, 0.56956687,
#        0.88464633, 0.83319955, 0.39399039, 0.53367122, 0.42567916,
#        0.845933  , 0.32533674, 0.5360943 , 0.21061631, 0.72364383,
#        0.95196807, 0.42356956, 0.81012622, 0.3417695 , 0.33479512,
#        0.83203546, 0.4871913 , 0.83691695, 0.23935947, 0.82847496,
#        0.55377162, 0.9309329 , 0.9142363 , 0.00801657, 0.63056626,
#        0.75833462, 0.02358942, 0.82182567, 0.21439889, 0.37398933,
#        0.25987663, 0.98838232, 0.66341938, 0.14842745, 0.5041664 ])

# %%
plt.title("Never")
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(gp_1, gp_2)
plt.show()
